# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Ajouter le chemin racine à sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# Dans leur Jupyter Notebook:
from Python.Backend.recup_data import recup_travel, recup_users

# Charger les deux datasets directement depuis le cloud:
df_users = recup_users()
df_travel = recup_travel()

# df_users est prêt pour la modélisation !
print(df_users.shape)
# Out:
# Succès : Données de la table 'users_generated' chargées. (1505 lignes)
# Succès : Données de la table 'travel_generated' chargées. (8209 lignes)
# (1505, 12)

# %%
df_users.tail(5)
# Out:
#      traveler_user_id traveler_name traveler_age traveler_gender  \
# 1500            Vince       Vincent           22            Male
# 1501             Vinc       Vincent           22            Male
# 1502              Mor       Vincent           22            Male
# 1503            Morin       Vincent           22            Male
# 1504           Mathia       Mathias           22            Male
#
#      traveler_nationality     profile_type climate_pref primary_dest_type  \
# 1500               French  Aventure/Nature         Cold  Adventure/Nature
# 1501             American  Aventure/Nature         Cold  Adventure/Nature
# 1502             American  Aventure/Nature         Cold  Adventure/Nature
# 1503             American  Aventure/Nature         Cold  Adventure/Nature
# 1504               French  Exotique/Budget          Hot   Cultural/Nature
#
#      acc_pref        transport_core_modes traveler_continent mot_de_passe
# 1500   Airbnb                     Bus;4x4             Europe          aaa
# 1501   Airbnb                         Bus             Africa          aaa
# 1502   Airbnb          Transports Publics             Africa          aaa
# 1503   Airbnb                         Bus             Africa           aa
# 1504    Villa  Bateau;Voiture;Tuk-Tuk;4x4             Europe           aa

# %%
liste = list(df_users["traveler_nationality"].unique()).sort()

# %%
df_users["transport_core_modes"].astype(str).str.split(";")
# Out:
# 0       [Voiture (si isolé), Randonnée, Scooter]
# 1             [Bus, Tuk-Tuk, Transports Publics]
# 2                        [Voiture, Tuk-Tuk, Bus]
# 3                      [Métro, Tuk-Tuk, Voiture]
# 4                      [Vélo, Marche, Randonnée]
#                           ...
# 1500                                  [Bus, 4x4]
# 1501                                       [Bus]
# 1502                        [Transports Publics]
# 1503                                       [Bus]
# 1504             [Bateau, Voiture, Tuk-Tuk, 4x4]
# Name: transport_core_modes, Length: 1505, dtype: object

# %%
df_travel[df_travel["User ID"] == "U0001"].tail()
# Out:
#      Trip ID User ID          Destination  Start date    End date  \
# 0     T00001   U0001  Yellowstone NP, USA  2017-04-21  2017-05-03
# 8208  T08209   U0001        Paris, France  2025-12-02  2025-12-03
#
#       Duration (days) Traveler name Traveler age Traveler gender  \
# 0                  13        Rajesh           37            Male
# 8208                1        Rajesh           37            Male
#
#      Traveler nationality Accommodation type  Accommodation cost  \
# 0                  Indian         Guesthouse              734.47
# 8208               Indian             Airbnb              500.00
#
#       Average Daily Cost  Total cost Local Transport Mode
# 0                1053.95     1788.42                  4x4
# 8208             1050.00     1550.00   Transports Publics

# %% [markdown]
#     {'city': 'Rome', 'country': 'Italy', 'type': 'City', 'climate': 'Temperate', 'continent': 'Europe', 'cost_level': 'Medium', 'prestige': 4}

# %%
city = "Malé"
